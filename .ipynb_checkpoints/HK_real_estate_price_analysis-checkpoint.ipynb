# %% [markdown]
# ### Analysis Real Estate Prices in Hong Kong
# Author: KW.Loh, MsC Comp7103 Assignment Sem 1 2023<br>
# Email :mweng02@connect.hku.hk

# %%
### Library 
import numpy as np, pandas as pd , datetime as dt, pickle ,seaborn as sns
import matplotlib.pyplot as plt, matplotlib.gridspec as gs
from matplotlib.image import imread
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### STEP 1 Dataset : Residential real estate sold in the period 2016 - 2019 in Hong Kong
#
# The transaction dataset were obtained from a vendor that comprise of residential transaction in Hong kong from 2016 to 2019. There are 230,000++ records in the datasets and first fed into PreProcessing.Py to cleansing the datasets and the following new features had been created: <br> a) New Sales and Resales <br> b) Property_Type <br> c) Buildng Age <br> d) UnitSize <br> e) Floor Type <br>
#
# At the same time, I had developed GeoCoder.py to call the GOOGLE MAP API to collect the lattitude and longitude of the distinct projectname and selected POI such as MTR and stored at JSON file. Next, I had further created a few more feature based on the distance between the POI and selected project name. </br>
#
# All the data are stored in Data/ Folder and the details on how to execute the two python scripts are available in the PreProcessing.Py.
# <br>

# %%
### The dataset has been processed and pre-clean in PreProcessing.Py
with open('Data/TransactionData.pkl', 'rb') as file_name:
    HK = pickle.load(file_name)

# %%
HK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 238046 entries, 2019-12-31 to 2016-01-01
# Data columns (total 27 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Project_Name        238046 non-null  object
#  1   combined_address    238046 non-null  object
#  2   INST_DATE           238046 non-null  object
#  3   Sale_Type           238046 non-null  object
#  4   Property_Type       238046 non-null  object
#  5   Sale_Year           238046 non-null  int64
#  6   D_CODE              238046 non-null  object
#  7   BuildingAge         238046 non-null  int64
#  8   FLOOR               238046 non-null  int64
#  9   FloorType           238046 non-null  int64
#  10  UnitSize            238046 non-null  int64
#  11  TOTNFA              238046 non-null  float64
#  12  lat                 238046 non-null  float64
#  13  long                238046 non-null  float64
#  14  MRT                 238046 non-null  object
#  15  quarter             238046 non-null  object
#  16  Distance_To_CBD     238046 non-null  float64
#  17  Distance_TO_MRT     238046 non-null  float64
#  18  Distance_To_School  238046 non-null  float64
#  19  Distance_To_Mall    238046 non-null  float64
#  20  below_value         238046 non-null  int64
#  21  duplex              238046 non-null  int64
#  22  stair               238046 non-null  int64
#  23  parking             238046 non-null  int64
#  24  roof                238046 non-null  int64
#  25  NET_PSF             238046 non-null  int64
#  26  Transaction_Price   238046 non-null  float64
# dtypes: float64(8), int64(11), object(8)
# memory usage: 50.9+ MB

# %%
# Real estate size statistics(In square feet)# Price per square-meter statistics
HK.describe().applymap('{:,.2f}'.format).T
# Out:
#                          count          mean            std       min  \
# Sale_Year           238,046.00      2,017.47           1.11  2,016.00
# BuildingAge         238,046.00          1.89           1.24      0.00
# FLOOR               238,046.00         17.01          89.85      0.00
# FloorType           238,046.00          1.83           1.06      0.00
# UnitSize            238,046.00          1.98           0.88      1.00
# TOTNFA              238,046.00        562.10       1,212.37     79.00
# lat                 238,046.00         22.49           2.17    -43.60
# long                238,046.00        112.12          20.00   -121.89
# Distance_To_CBD     238,046.00        243.55       2,237.70      0.25
# Distance_TO_MRT     238,046.00          3.24          22.15      0.00
# Distance_To_School  238,046.00          2.83          22.18      0.00
# Distance_To_Mall    238,046.00          3.53          22.13      0.00
# below_value         238,046.00          0.01           0.10      0.00
# duplex              238,046.00          0.00           0.04      0.00
# stair               238,046.00          0.00           0.05      0.00
# parking             238,046.00          0.02           0.13      0.00
# roof                238,046.00          0.02           0.15      0.00
# NET_PSF             238,046.00     14,351.81       6,242.62      0.00
# Transaction_Price   238,046.00  8,569,024.29  11,943,340.83    100.00
#
#                              25%           50%           75%               max
# Sale_Year               2,017.00      2,017.00      2,018.00          2,019.00
# BuildingAge                 1.00          2.00          3.00              3.00
# FLOOR                       7.00         14.00         24.00         43,412.00
# FloorType                   1.00          2.00          3.00              4.00
# UnitSize                    1.00          2.00          2.00              5.00
# TOTNFA                    379.00        491.00        638.00        568,550.00
# lat                        22.30         22.33         22.38             54.81
# long                      114.11        114.17        114.20            172.72
# Distance_To_CBD             4.95          9.88         17.41         26,325.00
# Distance_TO_MRT             0.26          0.45          0.84            200.00
# Distance_To_School          0.16          0.25          0.40            200.00
# Distance_To_Mall            0.32          0.64          1.38            200.00
# below_value                 0.00          0.00          0.00              1.00
# duplex                      0.00          0.00          0.00              1.00
# stair                       0.00          0.00          0.00              1.00
# parking                     0.00          0.00          0.00              1.00
# roof                        0.00          0.00          0.00              1.00
# NET_PSF                10,549.00     13,600.00     17,072.00        800,000.00
# Transaction_Price   4,480,000.00  6,150,000.00  8,963,000.00  1,060,000,000.00

# %%
NFA_variance =  10 *1212.37
Net_PSF_variance = 10 *6242.62	
Price_variance = 10 * 11943340.83

# %%
HK = HK[(HK['NET_PSF'] <Net_PSF_variance) & (HK['TOTNFA'] > 200) & (HK['TOTNFA'] <NFA_variance) & (HK['Transaction_Price'] < Price_variance)
        &(HK['lat'] > 22) &(HK['long'] > 114)&(HK['FLOOR'] < 100) &(HK['Transaction_Price'] > 2000000)]
HK = HK[(HK['NET_PSF'] != 0) & (HK['Distance_TO_MRT'] != 200)] 
#HK = HK.drop(["CBD"],axis =1)
HK['MRT'] = HK['MRT'].astype(str)
HK = HK[:20000]

# %% [markdown]
# #### STEP 2 DATA MINING
# The Observation from the dataset description <br>
# #1) 75% of transaction are below 700 sqft ~ median is ~500 sqft ~ 75% stay 638 sqft <br>
# #2) The psf is going up from 11K in 2016 to 15K in 2019 and average transaction per month is about 5000 <br>
# #3) 75% percentile is 9 million. Median is HKD 6 million <br>
# #4) Only ~25% are new sales. Out of the remaining secondary sales, 43% of the transaction are 20 years old age building.
#
# Next, investigate the 3 questions in mind -->
# #6) Near MTR station has price premium about HKD 2000 per premium (500 m radius) for project more than 20 years old. No concrete MRT premium for new project<br>
# #7) Most expensive psf more focus on Kowloon Area (from the heat map).

# %%
# Real estate size statistics(In square feet)# Price per square-meter statistics
HK.describe().applymap('{:,.2f}'.format).T
# Out:
#                         count          mean           std           min  \
# Sale_Year           20,000.00      2,019.00          0.00      2,019.00
# BuildingAge         20,000.00          1.72          1.30          0.00
# FLOOR               20,000.00         17.35         12.87          0.00
# FloorType           20,000.00          1.85          1.06          0.00
# UnitSize            20,000.00          1.90          0.83          1.00
# TOTNFA              20,000.00        530.27        268.13        202.00
# lat                 20,000.00         22.35          0.06         22.20
# long                20,000.00        114.16          0.07        114.00
# Distance_To_CBD     20,000.00         10.54          6.26          0.27
# Distance_TO_MRT     20,000.00          0.78          1.01          0.00
# Distance_To_School  20,000.00          0.34          0.30          0.00
# Distance_To_Mall    20,000.00          1.08          1.19          0.00
# below_value         20,000.00          0.00          0.01          0.00
# duplex              20,000.00          0.00          0.04          0.00
# stair               20,000.00          0.00          0.05          0.00
# parking             20,000.00          0.00          0.01          0.00
# roof                20,000.00          0.01          0.08          0.00
# NET_PSF             20,000.00     16,124.70      5,181.74      2,083.00
# Transaction_Price   20,000.00  8,773,463.10  7,565,014.06  2,002,000.00
#
#                              25%           50%           75%             max
# Sale_Year               2,019.00      2,019.00      2,019.00        2,019.00
# BuildingAge                 0.00          2.00          3.00            3.00
# FLOOR                       8.00         15.00         25.00           79.00
# FloorType                   1.00          2.00          3.00            4.00
# UnitSize                    1.00          2.00          2.00            5.00
# TOTNFA                    370.00        470.00        600.25        3,677.00
# lat                        22.31         22.33         22.37           22.54
# long                      114.13        114.17        114.21          114.27
# Distance_To_CBD             5.02          9.28         12.96           29.98
# Distance_TO_MRT             0.24          0.46          0.79           12.56
# Distance_To_School          0.16          0.26          0.41            4.39
# Distance_To_Mall            0.33          0.68          1.54           13.03
# below_value                 0.00          0.00          0.00            1.00
# duplex                      0.00          0.00          0.00            1.00
# stair                       0.00          0.00          0.00            1.00
# parking                     0.00          0.00          0.00            1.00
# roof                        0.00          0.00          0.00            1.00
# NET_PSF                12,889.75     15,569.50     18,330.00       61,017.00
# Transaction_Price   5,400,000.00  6,988,500.00  9,250,000.00  118,750,000.00

# %%
HK["UnitSize"].value_counts()
# Out:
# 2    10083
# 1     6578
# 3     2321
# 4      828
# 5      190
# Name: UnitSize, dtype: int64

# %%
HK["FloorType"].value_counts()
# Out:
# 1    7503
# 2    5892
# 3    3691
# 4    1666
# 0    1248
# Name: FloorType, dtype: int64

# %%
HK["BuildingAge"].value_counts()
# Out:
# 3    8751
# 0    6106
# 2    2995
# 1    2148
# Name: BuildingAge, dtype: int64

# %%
HK["below_value"].value_counts()
# Out:
# 0    19998
# 1        2
# Name: below_value, dtype: int64

# %%
HK["Property_Type"].value_counts()
# Out:
# E    16355
# B     3645
# Name: Property_Type, dtype: int64

# %%
HK["stair"].value_counts()
# Out:
# 0    19958
# 1       42
# Name: stair, dtype: int64

# %%
HK["parking"].value_counts()
# Out:
# 0    19996
# 1        4
# Name: parking, dtype: int64

# %%
HK["duplex"].value_counts()
# Out:
# 0    19970
# 1       30
# Name: duplex, dtype: int64

# %%
HK["quarter"].value_counts()
# Out:
# 2019-Q4    11110
# 2019-Q3     8890
# Name: quarter, dtype: int64

# %% [markdown]
# #### Q1: New Home or Resale ?

# %%
new_psf = HK[(HK['Sale_Type']=='NEW')].resample('1M').mean()
old_psf = HK[(HK['Sale_Type']=='RESALE')].resample('1M').mean()
difference_psf = new_psf['NET_PSF'].mean() - old_psf['NET_PSF'].mean()

fig = plt.figure(1, figsize=(10,6))
grid = gs.GridSpec(2, 1, height_ratios=[1,1])
ax1 = plt.subplot(grid[0,0])

new_psf ['NET_PSF'].plot(ls='-.', c='orange', label='NEAR_MRT', ax=ax1)
old_psf['NET_PSF'].plot(ls='--', c='red', label='NOT NEAR MRT', ax=ax1)

new_psf['NET_PSF'].mean() - old_psf['NET_PSF'].mean()
# Out:
# 3245.7526605115

# %%
HK['Sale_Type'].groupby(HK['BuildingAge']).value_counts(sort=True)
# 3 is more than 20 years 
# 2 is 10- 20 years
# 1 is within 10 years 
# 0 new flat
# Out:
# BuildingAge  Sale_Type
# 0            NEW          6106
# 1            RESALE       2148
# 2            RESALE       2995
# 3            RESALE       8751
# Name: Sale_Type, dtype: int64

# %%
HK['Sale_Type'].groupby(HK['Sale_Year']).value_counts()
# Out:
# Sale_Year  Sale_Type
# 2019       RESALE       13894
#            NEW           6106
# Name: Sale_Type, dtype: int64

# %%
HK['Sale_Type'].groupby(HK['BuildingAge']).value_counts().plot(kind='pie',autopct= '%1.1f%%', figsize=(8,6))
# Out:
# <Axes: ylabel='Sale_Type'>

# %%
minton_0 = HK[HK['BuildingAge']==0].resample('1M').mean()
minton_1 = HK[HK['BuildingAge']==1].resample('1M').mean()
minton_2 = HK[HK['BuildingAge']==2].resample('1M').mean()
minton_3 = HK[HK['BuildingAge']==3].resample('1M').mean()
minton_count = HK.resample('1M').count()
fig = plt.figure(1, figsize=(10,6))
grid = gs.GridSpec(2, 1, height_ratios=[3,1])
ax1 = plt.subplot(grid[0,0])
ax2 = plt.subplot(grid[1,0])
minton_0['NET_PSF'].plot(ls='-', label='mean value_New', ax=ax1)
minton_1['NET_PSF'].plot(ls='-.', c='orange', label='mean value_within_10 years', ax=ax1)
minton_2['NET_PSF'].plot(ls='--', c='red', label='mean value_withn_10_20 years', ax=ax1)
minton_3['NET_PSF'].plot(ls='-', c='green', label='mean value_more than_20 years', ax=ax1)
ax1.set_title('Monthly Unit Price ($psm) change')
ax1.set_ylabel('NET_PSF')
ax1.legend(loc='upper left')
ax2.bar(minton_count.index, minton_count['Project_Name'], width=10)
ax2.set_ylabel('Units sold')
ax2.set_xticklabels('')
plt.tight_layout()
plt.show()

# %%
pricechange_new = minton_0['NET_PSF'].T[minton_0['NET_PSF'].index[-1]] / minton_0['NET_PSF'].T[minton_0['NET_PSF'].index[0]] -1
pricechange_10 = minton_1['NET_PSF'].T[minton_1['NET_PSF'].index[-1]] / minton_1['NET_PSF'].T[minton_1['NET_PSF'].index[0]] -1
pricechange_20 = minton_2['NET_PSF'].T[minton_2['NET_PSF'].index[-1]] / minton_2['NET_PSF'].T[minton_2['NET_PSF'].index[0]] -1
pricechange_old = minton_3['NET_PSF'].T[minton_3['NET_PSF'].index[-1]] / minton_3['NET_PSF'].T[minton_3['NET_PSF'].index[0]] -1
pricechange_new,pricechange_10,pricechange_20,pricechange_old
# Out:
# (0.0819751460813356,
#  -0.13537615948861392,
#  -0.09991022713984965,
#  -0.0373785732101094)

# %% [markdown]
# ### Q2 ) Near MRT or Not -->Location Premium ?

# %%
STATION = HK.groupby('MRT')[['NET_PSF','lat','long','Distance_TO_MRT']].mean().reset_index()

# %%
top_dollars = STATION.sort_values('NET_PSF', ascending=False).iloc[:10]
top_dollars
# Out:
#                       MRT       NET_PSF        lat        long  \
# 28        Kowloon Station  32984.371429  22.304274  114.162484
# 0       Admiralty Station  25029.400000  22.274984  114.161085
# 45     Nam Cheong Station  23572.607219  22.327271  114.154160
# 3         Central Station  23375.482759  22.277640  114.154168
# 60   Shek Kip Mei Station  22767.160000  22.332300  114.170504
# 55   Sai Ying Pun Station  22095.413249  22.285843  114.142571
# 24        Kai Tak Station  22024.824762  22.327481  114.197600
# 83       Wan Chai Station  21398.250000  22.271411  114.175897
# 21      Hong Kong Station  21383.567568  22.280909  114.152157
# 43  Mong Kok East Station  21004.911111  22.321457  114.177105
#
#     Distance_TO_MRT
# 28         0.194256
# 0          0.666409
# 45         0.079699
# 3          0.680551
# 60         0.459748
# 55         0.295223
# 24         0.550063
# 83         0.824358
# 21         0.566935
# 43         0.664878

# %%
#OVERALL = HK[(HK['Distance_TO_MRT'] < 0.5)].mean()
#OVERALL_ = HK[(HK['Distance_TO_MRT'] > 0.5)].mean()

NEW = HK[(HK['BuildingAge'] == 0 ) & (HK['Distance_TO_MRT'] < 0.5)].resample('1M').mean()
NEW_ = HK[(HK['BuildingAge'] == 0 ) & (HK['Distance_TO_MRT'] > 0.5)].resample('1M').mean()

WITHIN10 = HK[(HK['BuildingAge'] == 1 ) & (HK['Distance_TO_MRT'] < 0.5)].resample('1M').mean()
WITHIN10_ = HK[(HK['BuildingAge'] == 1 ) & (HK['Distance_TO_MRT'] > 0.5)].resample('1M').mean()

WITHIN20 = HK[(HK['BuildingAge'] == 2 ) & (HK['Distance_TO_MRT'] < 0.5)].resample('1M').mean()
WITHIN20_ = HK[(HK['BuildingAge'] == 2 ) & (HK['Distance_TO_MRT'] > 0.5)].resample('1M').mean()

OTHER = HK[(HK['BuildingAge'] == 3 ) & (HK['Distance_TO_MRT'] < 0.5)].resample('1M').mean()
OTHER_ = HK[(HK['BuildingAge'] == 3 ) & (HK['Distance_TO_MRT'] > 0.5)].resample('1M').mean()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True)
ax1, ax2, ax3, ax4 = axes.flatten()

NEW['NET_PSF'].plot(ls='-.', c='orange', label='NEAR_MRT', ax=ax1)
NEW_['NET_PSF'].plot(ls='--', c='red', label='NOT NEAR MRT', ax=ax1)
WITHIN10['NET_PSF'].plot(ls='-.', c='orange', label='NEAR_MRT', ax=ax2)
WITHIN10_['NET_PSF'].plot(ls='--', c='red', label='NOT NEAR MRT', ax=ax2)
WITHIN20['NET_PSF'].plot(ls='-.', c='orange', label='NEAR_MRT', ax=ax3)
WITHIN20_['NET_PSF'].plot(ls='--', c='red', label='NOT NEAR MRT', ax=ax3)
OTHER['NET_PSF'].plot(ls='-.', c='orange', label='NEAR_MRT', ax=ax4)
OTHER_['NET_PSF'].plot(ls='--', c='red', label='NOT NEAR MRT', ax=ax4)
ax1.set_title('NEW PROJECT')
ax2.set_title('WITHIN10')
ax3.set_title('WITHIN20')
ax4.set_title('ABOVE20')
ax2.set_ylabel('NET_PSF')
ax1.legend(loc='upper left')
plt.tight_layout()
plt.show()

# %%
PREMIUM_NEW = NEW - NEW_
PREMIUM_10 = WITHIN10 - WITHIN10_
PREMIUM_20 = WITHIN20 - WITHIN20_
PREMIUM_OLD = OTHER - OTHER_

# %%
fig = plt.figure(1, figsize=(10,6))
grid = gs.GridSpec(2, 1, height_ratios=[1,1])
ax1 = plt.subplot(grid[0,0])

PREMIUM_NEW['NET_PSF'].plot(ls='-.', c='orange', label='NEAR_MRT', ax=ax1)
PREMIUM_10['NET_PSF'].plot(ls='--', c='red', label='NOT NEAR MRT', ax=ax1)
PREMIUM_20['NET_PSF'].plot(ls='--', c='blue', label='NOT NEAR MRT', ax=ax1)
PREMIUM_OLD['NET_PSF'].plot(ls='--', c='green', label='NOT NEAR MRT', ax=ax1)
# Out:
# <Axes: >

# %%
PREIMIUM = [PREMIUM_NEW['NET_PSF'].mean(), PREMIUM_10['NET_PSF'].mean(),PREMIUM_20['NET_PSF'].mean(),PREMIUM_OLD['NET_PSF'].mean()]
PREIMIUM
# Out:
# [4701.015669980129, 3321.617285710374, 1959.8991665462318, 1052.6353650999151]

# %%
#3 --> before 2005 
#2--> 2005 -2010
#1 --> 2010-2016
#0 --> 2017 and above

# %% [markdown]
# #### Machine Learning Real Estate Prediction
# #### Step 3: Feature Selection and Drop the Column

# %%
from sklearn import preprocessing
from sklearn import metrics 
from sklearn.model_selection  import train_test_split
from sklearn.model_selection  import KFold, cross_val_score,RepeatedKFold
from sklearn.tree import DecisionTreeRegressor
from sklearn import linear_model

# %%
HK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20000 entries, 2019-12-31 to 2019-07-10
# Data columns (total 27 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Project_Name        20000 non-null  object
#  1   combined_address    20000 non-null  object
#  2   INST_DATE           20000 non-null  object
#  3   Sale_Type           20000 non-null  object
#  4   Property_Type       20000 non-null  object
#  5   Sale_Year           20000 non-null  int64
#  6   D_CODE              20000 non-null  object
#  7   BuildingAge         20000 non-null  int64
#  8   FLOOR               20000 non-null  int64
#  9   FloorType           20000 non-null  int64
#  10  UnitSize            20000 non-null  int64
#  11  TOTNFA              20000 non-null  float64
#  12  lat                 20000 non-null  float64
#  13  long                20000 non-null  float64
#  14  MRT                 20000 non-null  object
#  15  quarter             20000 non-null  object
#  16  Distance_To_CBD     20000 non-null  float64
#  17  Distance_TO_MRT     20000 non-null  float64
#  18  Distance_To_School  20000 non-null  float64
#  19  Distance_To_Mall    20000 non-null  float64
#  20  below_value         20000 non-null  int64
#  21  duplex              20000 non-null  int64
#  22  stair               20000 non-null  int64
#  23  parking             20000 non-null  int64
#  24  roof                20000 non-null  int64
#  25  NET_PSF             20000 non-null  int64
#  26  Transaction_Price   20000 non-null  float64
# dtypes: float64(8), int64(11), object(8)
# memory usage: 4.3+ MB

# %%
HK = pd.get_dummies(HK, columns=['quarter', 
                                    #'Sale_Year_a'
                                   ], drop_first=False)

# %%
le = preprocessing.LabelEncoder()
for column in HK.describe(include='object').columns:
    HK[column] = le.fit_transform(HK[column])

# %%
HK = HK.fillna('')

# %%
pearson = HK.corr('pearson')
pearson.iloc[-1][:-1].sort_values()
# Out:
# quarter_2019-Q3      -1.000000
# long                 -0.075980
# D_CODE               -0.049697
# Distance_To_CBD      -0.035711
# FLOOR                -0.029709
# lat                  -0.020940
# Project_Name         -0.020057
# Distance_To_School   -0.019884
# Transaction_Price    -0.019620
# roof                 -0.017796
# NET_PSF              -0.016670
# combined_address     -0.015658
# TOTNFA               -0.010020
# UnitSize             -0.007021
# MRT                  -0.006171
# parking              -0.001580
# FloorType             0.003248
# duplex                0.003471
# below_value           0.008946
# stair                 0.010263
# Property_Type         0.027315
# Distance_To_Mall      0.027813
# BuildingAge           0.031355
# Sale_Type             0.041924
# Distance_TO_MRT       0.064122
# INST_DATE             0.859824
# Sale_Year                  NaN
# Name: quarter_2019-Q4, dtype: float64

# %%
# Correlation matrix as heatmap (seaborn)
fig, ax = plt.subplots(figsize=(14,10))
sns.heatmap(pearson, annot=True, annot_kws=dict(size=12), vmin=-1, vmax=1, ax=ax, cmap="YlGnBu")
plt.tight_layout()
plt.show()

# %%
HK_ = HK.drop(['INST_DATE','Project_Name','Sale_Year','MRT','TOTNFA','D_CODE','Transaction_Price','FLOOR','UnitSize',"NET_PSF"],axis =1)
xHK_ = HK.drop(['INST_DATE','Project_Name','Sale_Year','MRT','TOTNFA','D_CODE','Transaction_Price','FLOOR','UnitSize','Distance_TO_MRT',"NET_PSF"],axis =1)
y = HK['NET_PSF']

# %%
HK_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 20000 entries, 2019-12-31 to 2019-07-10
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   combined_address    20000 non-null  int32
#  1   Sale_Type           20000 non-null  int32
#  2   Property_Type       20000 non-null  int32
#  3   BuildingAge         20000 non-null  int64
#  4   FloorType           20000 non-null  int64
#  5   lat                 20000 non-null  float64
#  6   long                20000 non-null  float64
#  7   Distance_To_CBD     20000 non-null  float64
#  8   Distance_TO_MRT     20000 non-null  float64
#  9   Distance_To_School  20000 non-null  float64
#  10  Distance_To_Mall    20000 non-null  float64
#  11  below_value         20000 non-null  int64
#  12  duplex              20000 non-null  int64
#  13  stair               20000 non-null  int64
#  14  parking             20000 non-null  int64
#  15  roof                20000 non-null  int64
#  16  quarter_2019-Q3     20000 non-null  uint8
#  17  quarter_2019-Q4     20000 non-null  uint8
# dtypes: float64(6), int32(3), int64(7), uint8(2)
# memory usage: 2.4 MB

# %%
pearson = HK_.corr('pearson')
pearson.iloc[-1][:-1].sort_values()
# Correlation matrix as heatmap (seaborn)
fig, ax = plt.subplots(figsize=(14,10))
sns.heatmap(pearson, annot=True, annot_kws=dict(size=12), vmin=-1, vmax=1, ax=ax, cmap="YlGnBu")
plt.tight_layout()
plt.show()

# %%
# Split data into train and test leaving last ten (500) rows for the final evaluation
X_train, X_test, y_train, y_test = train_test_split(HK_.iloc[:-500], y.iloc[:-500], test_size=0.2)
xX_train, xX_test, xy_train, xy_test = train_test_split(xHK_.iloc[:-500], y.iloc[:-500], test_size=0.2)

# %%
print('Database size: {:g} \nTrain set size: {:g} \nTest set size: {:g} \nValidate set size: {:g}'
      .format(len(HK_), len(y_train), len(y_test), len(HK_)-(len(y_train)+len(y_test))))
# Out:
# Database size: 20000
# Train set size: 15600
# Test set size: 3900
# Validate set size: 500

# %%
# Scale data
scaler = preprocessing.StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### STEP 4 : APPLYING MACHINE LEARNING MODEL

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree  import DecisionTreeRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import explained_variance_score,mean_squared_error,r2_score

# %%
# Train & evaluate model performance
def train_and_evaluate(model, X, y):
    mol,score_,exp_var,r2_,mse_ = [],[],[],[],[]
    model.fit(X, y)
    print('Score on training set: {:g}'.format(model.score(X, y)))
    # k-fold cross validation iterator of 5 folds
    cv = KFold(n_splits=5, shuffle=True, random_state=1)
    scores = cross_val_score(model, X, y, cv=cv)
    print('Score using 5-fold cross-validation: {:g} +/- {:g}'.format(np.mean(scores), np.std(scores)*2)) 
    return np.mean(scores), np.std(scores)*2

# %%
# DecisionTreeRegressor
tree = DecisionTreeRegressor()
xtree = DecisionTreeRegressor()
score_R2_train_tree, error_train_tree = train_and_evaluate(tree, X_train, y_train.ravel())
xMTR_R2_train_tree, xMTR_train_tree = train_and_evaluate(xtree, xX_train, xy_train.ravel())
# Out:
# Score on training set: 0.97408
# Score using 5-fold cross-validation: 0.810979 +/- 0.00996839
# Score on training set: 0.974808
# Score using 5-fold cross-validation: 0.815474 +/- 0.00986297

# %%
# Test model prediction on test data
y_pred = tree.predict(X_test)
score_R2_test_tree , error_test_tree = metrics.r2_score(y_test, y_pred),metrics.mean_squared_error(y_test, y_pred)

xy_pred = xtree.predict(xX_test)
xMTR_R2_test_tree , xMTR_test_tree = metrics.r2_score(xy_test, xy_pred),metrics.mean_squared_error(xy_test, xy_pred)

# %%
# RandomForrestRegressor
forrest = RandomForestRegressor()
score_R2_train_rf, error_train_rf = train_and_evaluate(forrest, X_train, y_train.ravel())
xforrest = RandomForestRegressor()
xMTR_R2_train_rf, xMTR_train_rf = train_and_evaluate(xforrest, xX_train, xy_train.ravel())
# Out:
# Score on training set: 0.963378
# Score using 5-fold cross-validation: 0.875272 +/- 0.0058465
# Score on training set: 0.964223
# Score using 5-fold cross-validation: 0.877704 +/- 0.00412836

# %%
# Test model prediction on test data
y_pred = forrest.predict(X_test)
score_R2_test_rf , error_test_rf = metrics.r2_score(y_test, y_pred),metrics.mean_squared_error(y_test, y_pred)

xy_pred = xforrest.predict(xX_test)
xMTR_R2_test_rf , xMTR_test_rf = metrics.r2_score(xy_test, xy_pred),metrics.mean_squared_error(xy_test, xy_pred)

# %%
# Random Forests (Extra Trees)
clf_et = ExtraTreesRegressor()
score_R2_train_et, error_train_et  = train_and_evaluate(clf_et, X_train, y_train.ravel())
xclf_et = ExtraTreesRegressor()
xMTR_R2_train_et, xMTR_train_et  = train_and_evaluate(xclf_et, xX_train, xy_train.ravel())
# Out:
# Score on training set: 0.97408
# Score using 5-fold cross-validation: 0.859955 +/- 0.00523907
# Score on training set: 0.974808
# Score using 5-fold cross-validation: 0.862211 +/- 0.00674929

# %%
# Test model prediction on test data
y_pred = clf_et.predict(X_test)
score_R2_test_et , error_test_et = metrics.r2_score(y_test, y_pred),metrics.mean_squared_error(y_test, y_pred)

xy_pred = xclf_et.predict(xX_test)
xMTR_R2_test_et , xMTR_test_et = metrics.r2_score(xy_test, xy_pred),metrics.mean_squared_error(xy_test, xy_pred)

# %%
# Gradient Boosting Regressor
clf_gb = GradientBoostingRegressor(loss='absolute_error', max_depth=10, n_estimators=100)
score_R2_train_gb, error_train_gb  = train_and_evaluate(clf_gb, X_train, y_train.ravel())
xclf_gb = GradientBoostingRegressor(loss='absolute_error', max_depth=10, n_estimators=100)
xMTR_R2_train_gb, xMTR_train_gb  = train_and_evaluate(xclf_gb, xX_train, xy_train.ravel())
# Out:
# Score on training set: 0.8511
# Score using 5-fold cross-validation: 0.827318 +/- 0.00582235
# Score on training set: 0.849543
# Score using 5-fold cross-validation: 0.827869 +/- 0.00721874

# %%
# Test model prediction on test data
y_pred = clf_gb.predict(X_test)
score_R2_test_gb , error_test_gb = metrics.r2_score(y_test, y_pred),metrics.mean_squared_error(y_test, y_pred)

xy_pred = xclf_gb.predict(xX_test)
xMTR_R2_test_gb , xMTR_test_gb = metrics.r2_score(xy_test, xy_pred),metrics.mean_squared_error(xy_test, xy_pred)

# %%
lg = LGBMRegressor(n_estimators= 5000, max_depth=20, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
score_R2_train_lg, error_train_lg  = train_and_evaluate(lg, X_train, y_train.ravel())
xlg = LGBMRegressor(n_estimators= 5000, max_depth=20, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
xMTR_R2_train_lg, xMTR_train_lg  = train_and_evaluate(xlg, xX_train, xy_train.ravel())
# Out:
# Score on training set: 0.930695
# Score using 5-fold cross-validation: 0.881432 +/- 0.00271353
# Score on training set: 0.930287
# Score using 5-fold cross-validation: 0.883834 +/- 0.00511798

# %%
# Test model prediction on test data
y_pred = lg.predict(X_test)
score_R2_test_lg , error_test_lg = metrics.r2_score(y_test, y_pred),metrics.mean_squared_error(y_test, y_pred)

xy_pred = xlg.predict(xX_test)
xMTR_R2_test_lg , xMTR_test_lg = metrics.r2_score(xy_test, xy_pred),metrics.mean_squared_error(xy_test, xy_pred)

# %%
# Feature importance
feature_importance = lg.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig, ax = plt.subplots(figsize=(6,10))
ax.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, HK_.columns[sorted_idx])
ax.set_xlabel('Feature Relative Importance')
plt.tight_layout()
plt.show()

# %%
feature_importance = clf_et.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5
fig, ax = plt.subplots(figsize=(6,10))
ax.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, HK_.columns[sorted_idx])
ax.set_xlabel('Feature Relative Importance')
plt.tight_layout()
plt.show()

# %%
Model = ['DecisionTree','RandomForest','ExtraRandomForest','GradientBoosting','LightGBM']
R2_train = [score_R2_train_tree,score_R2_train_rf, score_R2_train_et, score_R2_train_gb,score_R2_train_lg]
R2_test = [score_R2_test_tree,score_R2_test_rf, score_R2_test_et, score_R2_test_gb,score_R2_test_lg]
R2_train_No_MTR = [xMTR_R2_train_tree,xMTR_R2_train_rf, xMTR_R2_train_et, xMTR_R2_train_gb,xMTR_R2_train_lg]
R2_test_No_MTR = [xMTR_R2_test_tree,xMTR_R2_test_rf, xMTR_R2_test_et, xMTR_R2_test_gb,xMTR_R2_test_lg]
MSE = [error_test_tree,error_test_rf,error_test_et,error_test_gb,error_test_lg]
xMSE = [xMTR_test_tree,xMTR_test_rf,xMTR_test_et,xMTR_test_gb,xMTR_test_lg]

# %%
result_base = pd.DataFrame(columns=['Model','R2_train','R2_test'])
result_xMTR = pd.DataFrame(columns=['Model','R2_train_No_MTR','R2_test_No_MTR'])

# %%
result_base['Model'] = Model
result_base['R2_train'] = R2_train
result_base['R2_test'] = R2_test
result_base['MSE'] = MSE

result_xMTR['Model'] = Model
result_xMTR['R2_train_No_MTR'] = R2_train_No_MTR
result_xMTR['R2_test_No_MTR'] = R2_test_No_MTR
result_base['xMSE'] = xMSE

# %%
result_base
# Out:
#                Model  R2_train   R2_test           MSE          xMSE
# 0       DecisionTree  0.810979  0.825323  5.567964e+06  5.650720e+06
# 1       RandomForest  0.875272  0.883113  3.725865e+06  3.806127e+06
# 2  ExtraRandomForest  0.859955  0.869436  4.161834e+06  4.264988e+06
# 3   GradientBoosting  0.827318  0.835148  5.254783e+06  5.228967e+06
# 4           LightGBM  0.881432  0.888700  3.547773e+06  3.651728e+06

# %%
result_xMTR
# Out:
#                Model  R2_train_No_MTR  R2_test_No_MTR
# 0       DecisionTree         0.815474        0.816958
# 1       RandomForest         0.877704        0.876709
# 2  ExtraRandomForest         0.862211        0.861845
# 3   GradientBoosting         0.827869        0.830620
# 4           LightGBM         0.883834        0.881711

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree  import DecisionTreeRegressor
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import explained_variance_score,mean_squared_error,r2_score

# %%
def getmodel(name):
    if name=="tree":
        return DecisionTreeRegressor()
    elif name=="rf":
        return RandomForestRegressor()
    elif name=="et":
        return ExtraTreesRegressor()
    elif name=="lg":
        return LGBMRegressor(n_estimators= 5000, max_depth=20, random_state=123, n_jobs=4, reg_alpha=0.1, reg_lambda=0.9)
    elif name == "gb":
        return GradientBoostingRegressor(loss='absolute_error', max_depth=10, n_estimators=100)

# %%
# Train & evaluate model performance
def train_and_evaluate(model, X, y,X_test,y_test):
    model.fit(X, y)
    print('Score on training set: {:g}'.format(model.score(X, y)))
    # k-fold cross validation iterator of 5 folds
    cv = KFold(n_splits=5, shuffle=True, random_state=1)
    scores = cross_val_score(model, X, y, cv=cv)
    print('Score using 5-fold cross-validation: {:g} +/- {:g}'.format(np.mean(scores), np.std(scores)*2)) 
    y_pred = model.predict(X_test)
    return np.mean(scores), np.std(scores)*2,metrics.r2_score(y_test, y_pred),metrics.mean_squared_error(y_test, y_pred)

# %%
tree,forest ,clf_et ,clf_gb,lg = getmodel('tree'),getmodel('rf'),getmodel('et'),getmodel("gb"),getmodel("lg")
xtree,xforest ,xclf_et ,xclf_gb,xlg = getmodel('tree'),getmodel('rf'),getmodel('et'),getmodel("gb"),getmodel("lg")
ModelList= [tree,forest,clf_et,clf_gb,lg]
xModelList= [xtree,xforest,xclf_et,xclf_gb,xlg]

# %%
R2_train,R2_test,MSE = [],[],[]
for model in ModelList:
    a,b,c,d = train_and_evaluate2(model, X_train, y_train.ravel(),X_test,y_test)
    R2_train.append(a)
    R2_test.append(c)
    MSE.append(d)
# Out:
# Score on training set: 0.968177
# Score using 5-fold cross-validation: 0.678789 +/- 0.0290129
# Score on training set: 0.947653
# Score using 5-fold cross-validation: 0.78683 +/- 0.0241298
# Score on training set: 0.968177
# Score using 5-fold cross-validation: 0.768834 +/- 0.0267433
# Score on training set: 0.866252
# Score using 5-fold cross-validation: 0.768027 +/- 0.017561
# Score on training set: 0.947251
# Score using 5-fold cross-validation: 0.762862 +/- 0.0257933

# %%
R2_train_No_MTR,R2_test_No_MTR,xMSE = [],[],[]
for model in xModelList:
    a,b,c,d = train_and_evaluate(model, xX_train, xy_train.ravel(),xX_test,xy_test)
    R2_train_No_MTR.append(a)
    R2_test_No_MTR.append(b)
    xMSE.append(d)
# Out:
# Score on training set: 0.967041
# Score using 5-fold cross-validation: 0.668084 +/- 0.0711824
# Score on training set: 0.947301
# Score using 5-fold cross-validation: 0.784305 +/- 0.0415351
# Score on training set: 0.967041
# Score using 5-fold cross-validation: 0.76557 +/- 0.0378696
# Score on training set: 0.871582
# Score using 5-fold cross-validation: 0.7668 +/- 0.0507099
# Score on training set: 0.945715
# Score using 5-fold cross-validation: 0.767195 +/- 0.0323608

# %%
#Model = ['DecisionTree','RandomForest']
Model = ['DecisionTree','RandomForest','ExtraRandomForest','GradientBoosting','LightGBM']

# %%
result_base = pd.DataFrame(columns=['Model','R2_train','R2_test'])
result_xMTR = pd.DataFrame(columns=['Model','R2_train_No_MTR','R2_test_No_MTR'])

# %%
result_base['Model'] = Model
result_base['R2_train'] = R2_train
result_base['R2_test'] = R2_test
result_base['MSE'] = MSE

result_xMTR['Model'] = Model
result_xMTR['R2_train_No_MTR'] = R2_train_No_MTR
result_xMTR['R2_test_No_MTR'] = R2_test_No_MTR
result_xMTR['xMSE'] = xMSE

# %%
result_base
# Out:
#                Model  R2_train   R2_test           MSE
# 0       DecisionTree  0.678789  0.713437  7.984445e+06
# 1       RandomForest  0.786830  0.807094  5.374897e+06
# 2  ExtraRandomForest  0.768834  0.782938  6.047947e+06
# 3   GradientBoosting  0.768027  0.788552  5.891527e+06
# 4           LightGBM  0.762862  0.793397  5.756544e+06

# %%
result_xMTR
# Out:
#                Model  R2_train_No_MTR  R2_test_No_MTR          xMSE
# 0       DecisionTree         0.668084        0.071182  7.938220e+06
# 1       RandomForest         0.784305        0.041535  5.505212e+06
# 2  ExtraRandomForest         0.765570        0.037870  6.128802e+06
# 3   GradientBoosting         0.766800        0.050710  5.990160e+06
# 4           LightGBM         0.767195        0.032361  5.783398e+06

# %%
feature_importance = clf_et.feature_importances_
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

# %%
# Feature importance
feature_importance_ = lg.feature_importances_
feature_importance_ = 100.0 * (feature_importance_ / feature_importance_.max())
sorted_idx_ = np.argsort(feature_importance_)
pos_ = np.arange(sorted_idx_.shape[0]) + .5

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=False)
ax1, ax2 = axes.flatten()
ax1.barh(pos, feature_importance[sorted_idx], align='center')
ax2.barh(pos_, feature_importance_[sorted_idx_], align='center')
ax1.set(yticks=pos, yticklabels=np.array(HK_.columns[sorted_idx]))
ax2.set(yticks=pos_, yticklabels=np.array(HK_.columns[sorted_idx_]))
ax1.set_xlabel('ExtraRandomForest')
ax2.set_xlabel('LightGBM')
plt.tight_layout()
plt.show()

# %%
# Pedict price for new apartments (not seen before)
x_new = HK_.iloc[-500:]  # example
# Scale data
x_new = scaler.transform(x_new)
xx_new = HK_.iloc[-500:]
xx_new = xx_new.drop(['Distance_TO_MRT'],axis =1)
# True values (actual prices)
true_values = y.iloc[-500:].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 500 entries, 2019-07-15 to 2019-07-10
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   combined_address    500 non-null    int32
#  1   Sale_Type           500 non-null    int32
#  2   Property_Type       500 non-null    int32
#  3   BuildingAge         500 non-null    int64
#  4   FloorType           500 non-null    int64
#  5   lat                 500 non-null    float64
#  6   long                500 non-null    float64
#  7   Distance_To_CBD     500 non-null    float64
#  8   Distance_TO_MRT     500 non-null    float64
#  9   Distance_To_School  500 non-null    float64
#  10  Distance_To_Mall    500 non-null    float64
#  11  below_value         500 non-null    int64
#  12  duplex              500 non-null    int64
#  13  stair               500 non-null    int64
#  14  parking             500 non-null    int64
#  15  roof                500 non-null    int64
#  16  quarter_2019-Q3     500 non-null    uint8
#  17  quarter_2019-Q4     500 non-null    uint8
# dtypes: float64(6), int32(3), int64(7), uint8(2)
# memory usage: 61.5 KB

# %% [markdown]
# ### Prediction Unseen Data

# %%
prediction, errorList = [],[]
for model in ModelList:
    xxx = model.predict(x_new)
    error =  (1.-xxx/true_values)*100.
    prediction.append(xxx)
    errorList.append(error)

# %%
xprediction, xerrorList = [],[]
for model in xModelList:
    xxx = model.predict(xx_new)
    error =  (1.-xxx/true_values)*100.
    xprediction.append(xxx)
    xerrorList.append(error)

# %%
prediction_MTR= pd.DataFrame(columns=['Model','error','errorx'])
prediction_MTR['Model'] = Model
error = np.array(errorList)
xerror = np.array(xerrorList)
prediction_MTR['error'] = [error[0].mean(),error[1].mean(),error[2].mean(),error[3].mean(),error[4].mean()]
prediction_MTR['errorx'] = [xerror[0].mean(),xerror[1].mean(),xerror[2].mean(),xerror[3].mean(),xerror[4].mean()]

# %%
prediction_MTR
# Out:
#                Model     error    errorx
# 0       DecisionTree -1.847391 -2.444591
# 1       RandomForest -1.779016 -2.117791
# 2  ExtraRandomForest -2.041350 -2.442732
# 3   GradientBoosting -2.458268 -2.532526
# 4           LightGBM -1.828630 -2.501483
